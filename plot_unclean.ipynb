# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
unclean_data = pd.read_csv('asli_tatti.csv')
unclean_data.columns = ['Entity', 'Code', 'Year', 'Schizophrenia disorders', 'Depressive disorders', 'Anxiety disorders', 'Bipolar disorder', 'Eating disorders']

unclean_data.head()
# Out:
#         Entity Code    Year  Schizophrenia disorders  Depressive disorders  \
# 0  Afghanistan  AFG  1990.0                 0.223206              4.996118
# 1  Afghanistan  AFG     NaN                 0.222454                   NaN
# 2  Afghanistan  AFG  1992.0                 0.221751              4.981346
# 3  Afghanistan  AFG  1993.0                 0.220987              4.976958
# 4  Afghanistan  AFG  1994.0                 0.220183              4.977782
#
#    Anxiety disorders  Bipolar disorder  Eating disorders
# 0           4.713314          0.703023          0.127700
# 1           4.702100          0.702069          0.123256
# 2           4.683743          0.700792               NaN
# 3           4.673549               NaN          0.115089
# 4                NaN          0.699898          0.111815

# %%
# # Assuming 'unclean_data' has been loaded as per your structure
# import pandas as pd
# import plotly.express as px

# # Fill NaN in 'Year' with a placeholder (if dropping is not preferred)
# unclean_data['Year'] = unclean_data['Year'].fillna('Missing Year')

# # Convert 'Year' to string to ensure consistent data type
# unclean_data['Year'] = unclean_data['Year'].astype(str)

# # Add a column to indicate missing data status for each disorder
# for disorder in ['Schizophrenia disorders', 'Depressive disorders', 'Anxiety disorders', 'Bipolar disorder', 'Eating disorders']:
#     unclean_data[f"{disorder} Missing"] = unclean_data[disorder].isna().map({True: "Missing", False: "Present"})

# # Melt the DataFrame to work with Plotly Express sunburst, ensuring no NaN values in 'Year'
# melted_data = unclean_data.melt(id_vars=['Entity', 'Year'], value_vars=[f"{disorder} Missing" for disorder in ['Schizophrenia disorders', 'Depressive disorders', 'Anxiety disorders', 'Bipolar disorder', 'Eating disorders']], var_name='Disorder Status', value_name='Status')

# # Create a sunburst chart, ensuring no 'Year' is NaN
# fig = px.sunburst(melted_data, path=['Entity', 'Year', 'Disorder Status', 'Status'], title="Hierarchical Missing Data Exploration")
# fig.show()

# %%
import plotly.express as px

# Highlight anomalies or missing data in the dataset
unclean_data['Anomaly'] = unclean_data[['Schizophrenia disorders', 'Depressive disorders', 'Anxiety disorders', 'Bipolar disorder', 'Eating disorders']].isna().any(axis=1)

# Plot a SPLOM with anomaly highlighting
fig = px.scatter_matrix(unclean_data,
                        dimensions=['Schizophrenia disorders', 'Depressive disorders', 'Anxiety disorders', 'Bipolar disorder', 'Eating disorders'],
                        color='Anomaly',
                        title="Scatter Plot Matrix with Anomaly Highlighting",
                        symbol='Anomaly',
                        labels={col: col.replace('_', ' ') for col in unclean_data.columns})  # Improve readability
fig.update_traces(diagonal_visible=False)  # Hide histograms on the diagonal
fig.show()
